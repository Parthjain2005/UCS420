# %% [markdown]
# <a href="https://colab.research.google.com/github/Parthjain2005/UCS420/blob/main/Assignment_3_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Q1

# %%
import pandas as pd
df = pd.read_csv('table.csv')

# %% [markdown]
# Q2

# %%
df.iloc[[0,4,7,8]]
# Out:
#    Tid Refund Marital Status  Taxable Income Cheat
# 0    1    Yes         Single          125000    No
# 4    5     No       Divorced           95000   Yes
# 7    8     No         Single           85000   Yes
# 8    9     No        Married           75000    No

# %% [markdown]
# Q3

# %%
df.iloc[3:8]
# Out:
#    Tid Refund Marital Status  Taxable Income Cheat
# 3    4    Yes        Married          120000    No
# 4    5     No       Divorced           95000   Yes
# 5    6     No        Married           60000    No
# 6    7    Yes       Divorced          220000    No
# 7    8     No         Single           85000   Yes

# %%
df.iloc[4:9,2:5]
# Out:
#   Marital Status  Taxable Income Cheat
# 4       Divorced           95000   Yes
# 5        Married           60000    No
# 6       Divorced          220000    No
# 7         Single           85000   Yes
# 8        Married           75000    No

# %%
df.iloc[:,1:4]
# Out:
#   Refund Marital Status  Taxable Income
# 0    Yes         Single          125000
# 1     No        Married          100000
# 2     No         Single           70000
# 3    Yes        Married          120000
# 4     No       Divorced           95000
# 5     No        Married           60000
# 6    Yes       Divorced          220000
# 7     No         Single           85000
# 8     No        Married           75000
# 9     No         Single           90000

# %% [markdown]
# Q4

# %%
df_new = pd.read_csv('Iris.csv')
df_new.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# Q5

# %%
df_new.drop(3,axis=0)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 4      5            5.0           3.6            1.4           0.2
# 5      6            5.4           3.9            1.7           0.4
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 4       Iris-setosa
# 5       Iris-setosa
# ..              ...
# ...

# %%
df_new.drop(df_new.columns[2],axis=1)
# Out:
#       Id  SepalLengthCm  PetalLengthCm  PetalWidthCm         Species
# 0      1            5.1            1.4           0.2     Iris-setosa
# 1      2            4.9            1.4           0.2     Iris-setosa
# 2      3            4.7            1.3           0.2     Iris-setosa
# 3      4            4.6            1.5           0.2     Iris-setosa
# 4      5            5.0            1.4           0.2     Iris-setosa
# ..   ...            ...            ...           ...             ...
# 145  146            6.7            5.2           2.3  Iris-virginica
# 146  147            6.3            5.0           1.9  Iris-virginica
# 147  148            6.5            5.2           2.0  Iris-virginica
# 148  149            6.2            5.4           2.3  Iris-virginica
# 149  150            5.9            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# Q6

# %%
df_emp = pd.read_csv('employees.csv')

# %%
print("Shape of DataFrame:", df_emp.shape)
# Out:
# Shape of DataFrame: (5, 10)

# %%
print("\nSummary of DataFrame:")
print(df_emp.info())
# Out:
# Summary of DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Employee_ID          5 non-null      int64
#  1   Name                 5 non-null      object
#  2   Department           5 non-null      object
#  3   Age                  5 non-null      int64
#  4   Salary               5 non-null      int64
#  5   Years_of_Experience  5 non-null      int64
#  6   Joining_Date         5 non-null      object
#  7   Gender               5 non-null      object
#  8   Bonus                5 non-null      int64
#  9   Rating               5 non-null      float64
# dtypes: float64(1), int64(5), object(4)
# memory usage: 532.0+ bytes
# None

# %%
print("\nDescriptive Statistics:")
print(df_emp.describe())
# Out:
# Descriptive Statistics:
#        Employee_ID        Age       Salary  Years_of_Experience   Bonus  \
# count     5.000000   5.000000      5.00000             5.000000     5.0
# mean    103.000000  34.000000  60000.00000             7.400000  5500.0
# std       1.581139   5.612486   7905.69415             3.847077  1000.0
# min     101.000000  28.000000  50000.00000             3.000000  4500.0
# 25%     102.000000  29.000000  55000.00000             4.000000  5000.0
# 50%     103.000000  34.000000  60000.00000             8.000000  5000.0
# 75%     104.000000  38.000000  65000.00000            10.000000  6000.0
# max     105.000000  41.000000  70000.00000            12.000000  7000.0
#
#          Rating
# count  5.000000
# mean   4.100000
# std    0.494975
# min    3.500000
# 25%    3.800000
# 50%    4.000000
# 75%    4.500000
# max    4.700000

# %%
print("\nFirst 5 rows:\n", df_emp.head())
print("\nLast 3 rows:\n", df_emp.tail(3))
# Out:
# First 5 rows:
#     Employee_ID     Name Department  Age  Salary  Years_of_Experience  \
# 0          101    Alice         HR   29   50000                    4
# 1          102      Bob         IT   34   70000                    8
# 2          103  Charlie         IT   41   65000                   10
# 3          104    Diana  Marketing   28   55000                    3
# 4          105   Edward      Sales   38   60000                   12
#
#   Joining_Date  Gender  Bonus  Rating
# 0   15-03-2020  Female   5000     4.5
# 1   19-07-2017    Male   7000     4.0
# 2   01-06-2013    Male   6000     3.8
# 3   10-02-2021  Female   4500     4.7
# 4   25-11-2010    Male   5000     3.5
#
# Last 3 rows:
#     Employee_ID     Name Department  Age  Salary  Years_of_Experience  \
# 2          103  Charlie         IT   41   65000                   10
# 3          104    Diana  Marketing   28   55000                    3
# 4          105   Edward      Sales   38   60000                   12
#
# ...

# %%
print("\nAverage Salary:", df_emp["Salary"].mean())
print("Total Bonus Paid:", df_emp["Bonus"].sum())
print("Youngest Employee's Age:", df_emp["Age"].min())
print("Highest Performance Rating:", df_emp["Rating"].max())
# Out:
# Average Salary: 60000.0
# Total Bonus Paid: 27500
# Youngest Employee's Age: 28
# Highest Performance Rating: 4.7

# %%
df_emp_sorted = df_emp.sort_values(by="Salary", ascending=False)
print("\nDataFrame sorted by Salary:\n", df_emp_sorted)
# Out:
# DataFrame sorted by Salary:
#     Employee_ID     Name Department  Age  Salary  Years_of_Experience  \
# 1          102      Bob         IT   34   70000                    8
# 2          103  Charlie         IT   41   65000                   10
# 4          105   Edward      Sales   38   60000                   12
# 3          104    Diana  Marketing   28   55000                    3
# 0          101    Alice         HR   29   50000                    4
#
#   Joining_Date  Gender  Bonus  Rating
# 1   19-07-2017    Male   7000     4.0
# 2   01-06-2013    Male   6000     3.8
# 4   25-11-2010    Male   5000     3.5
# 3   10-02-2021  Female   4500     4.7
# 0   15-03-2020  Female   5000     4.5

# %%
def categorize_performance(rating):
    if rating >= 4.5:
        return "Excellent"
    elif rating >= 4.0:
        return "Good"
    else:
        return "Average"

df_emp["Performance_Category"] = df_emp["Rating"].apply(categorize_performance)
print("\nDataFrame with Performance Categories:\n", df_emp)
# Out:
# DataFrame with Performance Categories:
#     Employee_ID     Name Department  Age  Salary  Years_of_Experience  \
# 0          101    Alice         HR   29   50000                    4
# 1          102      Bob         IT   34   70000                    8
# 2          103  Charlie         IT   41   65000                   10
# 3          104    Diana  Marketing   28   55000                    3
# 4          105   Edward      Sales   38   60000                   12
#
#   Joining_Date  Gender  Bonus  Rating Performance_Category
# 0   15-03-2020  Female   5000     4.5            Excellent
# 1   19-07-2017    Male   7000     4.0                 Good
# 2   01-06-2013    Male   6000     3.8              Average
# 3   10-02-2021  Female   4500     4.7            Excellent
# 4   25-11-2010    Male   5000     3.5              Average

# %%
print("\nMissing values in DataFrame:\n", df_emp.isnull().sum())
# Out:
# Missing values in DataFrame:
#  Employee_ID             0
# Name                    0
# Department              0
# Age                     0
# Salary                  0
# Years_of_Experience     0
# Joining_Date            0
# Gender                  0
# Bonus                   0
# Rating                  0
# Performance_Category    0
# dtype: int64

# %%
df_emp.rename(columns={"Employee_ID": "ID"}, inplace=True)
print("\nRenamed DataFrame:\n", df_emp)
# Out:
# Renamed DataFrame:
#      ID     Name Department  Age  Salary  Years_of_Experience Joining_Date  \
# 0  101    Alice         HR   29   50000                    4   15-03-2020
# 1  102      Bob         IT   34   70000                    8   19-07-2017
# 2  103  Charlie         IT   41   65000                   10   01-06-2013
# 3  104    Diana  Marketing   28   55000                    3   10-02-2021
# 4  105   Edward      Sales   38   60000                   12   25-11-2010
#
#    Gender  Bonus  Rating Performance_Category
# 0  Female   5000     4.5            Excellent
# 1    Male   7000     4.0                 Good
# 2    Male   6000     3.8              Average
# 3  Female   4500     4.7            Excellent
# 4    Male   5000     3.5              Average

# %%
exp_5plus = df_emp[df_emp["Years_of_Experience"] > 5]
it_department = df_emp[df_emp["Department"] == "IT"]
print("\nEmployees with more than 5 years of experience:\n", exp_5plus)
print("\nEmployees in IT department:\n", it_department)
# Out:
# Employees with more than 5 years of experience:
#      ID     Name Department  Age  Salary  Years_of_Experience Joining_Date  \
# 1  102      Bob         IT   34   70000                    8   19-07-2017
# 2  103  Charlie         IT   41   65000                   10   01-06-2013
# 4  105   Edward      Sales   38   60000                   12   25-11-2010
#
#   Gender  Bonus  Rating Performance_Category
# 1   Male   7000     4.0                 Good
# 2   Male   6000     3.8              Average
# 4   Male   5000     3.5              Average
#
# Employees in IT department:
#      ID     Name Department  Age  Salary  Years_of_Experience Joining_Date  \
# 1  102      Bob         IT   34   70000                    8   19-07-2017
# 2  103  Charlie         IT   41   65000                   10   01-06-2013
#
#   Gender  Bonus  Rating Performance_Category
# 1   Male   7000     4.0                 Good
# 2   Male   6000     3.8              Average

# %%
df_emp["Tax"] = df_emp["Salary"] * 0.10
print("\nDataFrame with Tax column:\n", df_emp)
# Out:
# DataFrame with Tax column:
#      ID     Name Department  Age  Salary  Years_of_Experience Joining_Date  \
# 0  101    Alice         HR   29   50000                    4   15-03-2020
# 1  102      Bob         IT   34   70000                    8   19-07-2017
# 2  103  Charlie         IT   41   65000                   10   01-06-2013
# 3  104    Diana  Marketing   28   55000                    3   10-02-2021
# 4  105   Edward      Sales   38   60000                   12   25-11-2010
#
#    Gender  Bonus  Rating Performance_Category     Tax
# 0  Female   5000     4.5            Excellent  5000.0
# 1    Male   7000     4.0                 Good  7000.0
# 2    Male   6000     3.8              Average  6500.0
# 3  Female   4500     4.7            Excellent  5500.0
# 4    Male   5000     3.5              Average  6000.0

# %%
df_emp.to_csv("modified_employees.csv", index=False)
print("\nModified DataFrame saved to 'modified_employees.csv'")
# Out:
# Modified DataFrame saved to 'modified_employees.csv'
