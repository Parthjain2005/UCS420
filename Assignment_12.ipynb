# %% [markdown]
# <a href="https://colab.research.google.com/github/Parthjain2005/UCS420/blob/main/Assignment_12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def get_bot_response(user_input):
    responses = {
        "hi": "Hello! I am HealthBot. How can I assist you today?",
        "hello": "Hello! I am HealthBot. How can I assist you today?",
        "headache": "You should rest, stay hydrated, and take a mild pain reliever if needed.",
        "fever": "Drink plenty of fluids and rest. If the fever persists, please consult a doctor.",
        "dizzy": "Sit down, breathe deeply, and drink water. If it continues, seek medical help.",
        "cold": "Warm fluids, soups, citrus fruits, and light meals help during a cold.",
        "healthy": "Eat balanced meals, exercise regularly, stay hydrated, and get enough sleep.",
        "cut": "Clean the wound with water, apply antiseptic, and cover it with a clean bandage.",
        "water": "Generally, 2 to 3 liters per day is recommended, but it varies based on your activity.",
        "thank you": "You’re welcome! Take care.",
        "bye": "Goodbye! Stay healthy."
    }
    return responses.get(user_input.lower(), "Sorry, I didn't understand that.")

def run_chatbot():
    print("HealthBot: Hello! I am HealthBot. How can I assist you today?")
    while True:
        user_input = input("You: ")
        if user_input.lower() in ['bye', 'exit', 'quit']:
            print("HealthBot: Goodbye! Stay healthy.")
            break
        bot_response = get_bot_response(user_input)
        print(f"HealthBot: {bot_response}")

if __name__ == "__main__":
    run_chatbot()
# Out:
# HealthBot: Hello! I am HealthBot. How can I assist you today?
# You: hello
# HealthBot: Hello! I am HealthBot. How can I assist you today?
# You: fever
# HealthBot: Drink plenty of fluids and rest. If the fever persists, please consult a doctor.
# You: bye
# HealthBot: Goodbye! Stay healthy.
